# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import os

url = "https://www.cbnu.ac.kr/www/selectBbsNttList.do?key=815&bbsNo=8&pageUnit=10&searchCtgry=%ED%95%99%EC%82%AC%2F%EC%9E%A5%ED%95%99&searchCnd=SJ&searchKrwd=%EC%9E%A5%ED%95%99"

response = requests.get(url)
soup = BeautifulSoup(response.text, "html.parser")

# %%
articles = soup.find("tbody", class_= 'text_center')
articles
# Out:
# <tbody class="text_center">
# <tr>
# <td>
# <span class="bbs_num">345</span>
# </td>
#
# <td class="p-subject">
# <a href="./selectBbsNttView.do;JSESSIONID=51EF6AC7E4896FA0BCCEB34182E3D608?key=815&amp;bbsNo=8&amp;nttNo=161037&amp;pageUnit=10&amp;searchCtgry=%ed%95%99%ec%82%ac%2f%ec%9e%a5%ed%95%99&amp;searchCnd=SJ&amp;searchKrwd=%ec%9e%a5%ed%95%99&amp;pageIndex=1" target="_top">
#
#
#
#
#
# 			                                            (재)고속도로장학재단 2025년 고속도로 장학생 선발 협조 요청
#
#
#
#
#
# 			                                            </a>
# </td>
# <td>
# <span class="p-icon p-icon__pdf">pdf 파일 첨부</span>
# </td>
# <td>
# 			                                            학생과
# 			                                    </td>
# <td>
# <!--<time>
#
#
#
# 												                	2025-09-09
#
#
# 			                                            </time>-->
# 								    2025-09-09
# 			                                    </td>
# <td class="hits" data-mask="#,##0" data-mask-reverse="true">
# 			                                            7
# 			                                    </td>
# </tr>
# <tr>
# <td>
# <span class="bbs_num">344</span>
# </td>
#
# <td class="p-subject">
# <a href="./selectBbsNttView.do;JSESSIONID=51EF6AC7E4896FA0BCCEB34182E3D608?key=815&amp;bbsNo=8&amp;nttNo=160989&amp;pageUnit=10&amp;searchCtgry=%ed%95%99%ec%82%ac%2f%ec%9e%a5%ed%95%99&amp;searchCnd=SJ&amp;searchKrwd=%ec%9e%a5%ed%95%99&amp;pageIndex=1" target="_top">
#
#
#
#
#
# 			                                            (재)삼원장학재단 제23기 후기 삼원 장학생 선발 안내
#
#
#
#
#
# 			                                            </a>
# </td>
# <td>
# <span class="p-icon p-icon__folder">여러개의 파일 첨부</span>
# </td>
# <td>
# 			                                            학생과
# 			                                    </td>
# <td>
# <!--<time>
#
#
#
# 												                	2025-09-08
#
#
# 			                                            </time>-->
# 								    2025-09-08
# 			                                    </td>
# <td class="hits" data-mask="#,##0" data-mask-reverse="true">
# 			                                            156
# 			                                    </td>
# </tr>
# <tr>
# <td>
# <span class="bbs_num">343</span>
# </td>
#
# <td class="p-subject">
# <a href="./selectBbsNttView.do;JSESSIONID=51EF6AC7E4896FA0BCCEB34182E3D608?key=815&amp;bbsNo=8&amp;nttNo=160935&amp;pageUnit=10&amp;searchCtgry=%ed%95%99%ec%82%ac%2f%ec%9e%a5%ed%95%99&amp;searchCnd=SJ&amp;searchKrwd=%ec%9e%a5%ed%95%99&amp;pageIndex=1" target="_top">
#
#
#
#
#
# 			                                            (재)인천인재평생교육진흥원 2025년 하반기 장학생 선발 안내
#
#
#
#
#
# 			                                            </a>
# </td>
# <td>
# <span class="p-icon p-icon__folder">여러개의 파일 첨부</span>
# </td>
# <td>
# 			                                            학생과
# 			                                    </td>
# <td>
# <!--<time>
#
#
#
# 												                	2025-09-04
#
#
# 			                                            </time>-->
# 								    2025-09-04
# 			                                    </td>
# <td class="hits" data-mask="#,##0" data-mask-reverse="true">
# 			                                            234
# 			                                    </td>
# </tr>
# <tr>
# <td>
# <span class="bbs_num">342</span>
# </td>
#
# <td class="p-subject">
# <a href="./selectBbsNttView.do;JSESSIONID=51EF6AC7E4896FA0BCCEB34182E3D608?key=815&amp;bbsNo=8&amp;nttNo=160885&amp;pageUnit=10&amp;searchCtgry=%ed%95%99%ec%82%ac%2f%ec%9e%a5%ed%95%99&amp;searchCnd=SJ&amp;searchKrwd=%ec%9e%a5%ed%95%99&amp;pageIndex=1" target="_top">
#
#
#
#
#
# 			                                            (재)경원장학재단 제6기 장학생 선발 안내
#
#
#
#
#
# 			                                            </a>
# </td>
# <td>
# <span class="p-icon p-icon__pdf">pdf 파일 첨부</span>
# </td>
# <td>
# 			                                            학생과
# 			                                    </td>
# <td>
# <!--<time>
#
#
#
# 												                	2025-09-03
#
#
# 			                                            </time>-->
# 								    2025-09-03
# 			                                    </td>
# <td class="hits" data-mask="#,##0" data-mask-reverse="true">
# 			                                            397
# 			                                    </td>
# </tr>
# <tr>
# <td>
# <span class="bbs_num">341</span>
# </td>
#
# <td class="p-subject">
# <a href="./selectBbsNttView.do;JSESSIONID=51EF6AC7E4896FA0BCCEB34182E3D608?key=815&amp;bbsNo=8&amp;nttNo=160873&amp;pageUnit=10&amp;searchCtgry=%ed%95%99%ec%82%ac%2f%ec%9e%a5%ed%95%99&amp;searchCnd=SJ&amp;searchKrwd=%ec%9e%a5%ed%95%99&amp;pageIndex=1" target="_top">
#
#
#
#
#
# 			                                            (재)경주시장학회 2025학년도 장학생 선발 안내
#
#
#
#
#
# 			                                            </a>
# </td>
# <td>
# <span class="p-icon p-icon__pdf">pdf 파일 첨부</span>
# </td>
# <td>
# 			                                            학생과
# 			                                    </td>
# <td>
# <!--<time>
#
#
#
# 												                	2025-09-03
#
#
# 			                                            </time>-->
# 								    2025-09-03
# 			                                    </td>
# <td class="hits" data-mask="#,##0" data-mask-reverse="true">
# 			                                            258
# 			                                    </td>
# </tr>
# <tr>
# <td>
# <span class="bbs_num">340</span>
# </td>
#
# <td class="p-subject">
# <a href="./selectBbsNttView.do;JSESSIONID=51EF6AC7E4896FA0BCCEB34182E3D608?key=815&amp;bbsNo=8&amp;nttNo=160822&amp;pageUnit=10&amp;searchCtgry=%ed%95%99%ec%82%ac%2f%ec%9e%a5%ed%95%99&amp;searchCnd=SJ&amp;searchKrwd=%ec%9e%a5%ed%95%99&amp;pageIndex=1" target="_top">
#
#
#
#
#
# 			                                            2025년 2학기 국가장학금 신청자 가구원 미동의자 동의 안내
#
#
#
#
#
# 			                                            </a>
# </td>
# <td>
# <span class="p-icon p-icon__folder">여러개의 파일 첨부</span>
# </td>
# <td>
# 			                                            학생과
# 			                                    </td>
# <td>
# <!--<time>
#
#
#
# 												                	2025-09-02
#
#
# 			                                            </time>-->
# 								    2025-09-02
# 			                                    </td>
# <td class="hits" data-mask="#,##0" data-mask-reverse="true">
# 			                                            307
# 			                                    </td>
# </tr>
# <tr>
# <td>
# <span class="bbs_num">339</span>
# </td>
#
# <td class="p-subject">
# <a href="./selectBbsNttView.do;JSESSIONID=51EF6AC7E4896FA0BCCEB34182E3D608?key=815&amp;bbsNo=8&amp;nttNo=160820&amp;pageUnit=10&amp;searchCtgry=%ed%95%99%ec%82%ac%2f%ec%9e%a5%ed%95%99&amp;searchCnd=SJ&amp;searchKrwd=%ec%9e%a5%ed%95%99&amp;pageIndex=1" target="_top">
#
#
#
#
#
# 			                                            국가유산진흥원  2025년 국가유산진흥원 전통 기·예능 분야 및 매장유산 관련 분야 우수 장학생 선발 안내
#
#
#
#
#
# 			                                            </a>
# </td>
# <td>
# <span class="p-icon p-icon__folder">여러개의 파일 첨부</span>
# </td>
# <td>
# 			                                            학생과
# 			                                    </td>
# <td>
# <!--<time>
#
#
#
# 												                	2025-09-02
#
#
# 			                                            </time>-->
# 								    2025-09-02
# 			                                    </td>
# <td class="hits" data-mask="#,##0" data-mask-reverse="true">
# 			                                            270
# 			                                    </td>
# </tr>
# <tr>
# <td>
# <span class="bbs_num">338</span>
# </td>
#
# <td class="p-subject">
# <a href="./selectBbsNttView.do;JSESSIONID=51EF6AC7E4896FA0BCCEB34182E3D608?key=815&amp;bbsNo=8&amp;nttNo=160781&amp;pageUnit=10&amp;searchCtgry=%ed%95%99%ec%82%ac%2f%ec%9e%a5%ed%95%99&amp;searchCnd=SJ&amp;searchKrwd=%ec%9e%a5%ed%95%99&amp;pageIndex=1" target="_top">
#
#
#
#
#
# 			                                            2025학년도 2학기 중소기업 취업연계 장학사업(희망사다리Ⅰ유형) 신규 장학생 신청 인내
#
#
#
#
#
# 			                                            </a>
# </td>
# <td>
# <span class="p-icon p-icon__folder">여러개의 파일 첨부</span>
# </td>
# <td>
# 			                                            학생과
# 			                                    </td>
# <td>
# <!--<time>
#
#
#
# 												                	2025-09-02
#
#
# 			                                            </time>-->
# 								    2025-09-02
# 			                                    </td>
# <td class="hits" data-mask="#,##0" data-mask-reverse="true">
# 			                                            354
# 			                                    </td>
# </tr>
# <tr>
# <td>
# <span class="bbs_num">337</span>
# </td>
#
# <td class="p-subject">
# <a href="./selectBbsNttView.do;JSESSIONID=51EF6AC7E4896FA0BCCEB34182E3D608?key=815&amp;bbsNo=8&amp;nttNo=160762&amp;pageUnit=10&amp;searchCtgry=%ed%95%99%ec%82%ac%2f%ec%9e%a5%ed%95%99&amp;searchCnd=SJ&amp;searchKrwd=%ec%9e%a5%ed%95%99&amp;pageIndex=1" target="_top">
#
#
#
#
#
# 			                                            한국산림복지진흥원 2025년 한국산림복지진흥원 녹색장학사업 장학생 선발 안내
#
#
#
#
#
# 			                                            </a>
# </td>
# <td>
# <span class="p-icon p-icon__folder">여러개의 파일 첨부</span>
# </td>
# <td>
# 			                                            학생과
# 			                                    </td>
# <td>
# <!--<time>
#
#
#
# 												                	2025-09-01
#
#
# 			                                            </time>-->
# 								    2025-09-01
# 			                                    </td>
# <td class="hits" data-mask="#,##0" data-mask-reverse="true">
# 			                                            375
# 			                                    </td>
# </tr>
# <tr>
# <td>
# <span class="bbs_num">336</span>
# </td>
#
# <td class="p-subject">
# <a href="./selectBbsNttView.do;JSESSIONID=51EF6AC7E4896FA0BCCEB34182E3D608?key=815&amp;bbsNo=8&amp;nttNo=160761&amp;pageUnit=10&amp;searchCtgry=%ed%95%99%ec%82%ac%2f%ec%9e%a5%ed%95%99&amp;searchCnd=SJ&amp;searchKrwd=%ec%9e%a5%ed%95%99&amp;pageIndex=1" target="_top">
#
#
#
#
#
# 			                                            (재)달서인재육성장학재단 2025학년도 하반기 장학생 선발
#
#
#
#
#
# 			                                            </a>
# </td>
# <td>
# <span class="p-icon p-icon__folder">여러개의 파일 첨부</span>
# </td>
# <td>
# 			                                            학생과
# 			                                    </td>
# <td>
# <!--<time>
#
#
#
# 												                	2025-09-01
#
#
# 			                                            </time>-->
# 								    2025-09-01
# 			                                    </td>
# <td class="hits" data-mask="#,##0" data-mask-reverse="true">
# 			                                            327
# 			                                    </td>
# </tr>
# </tbody>

# %%
texts = articles.find_all("td" class_="p-subject")
texts
# Out:
# [<tr>
#  <td>
#  <span class="bbs_num">345</span>
#  </td>
#
#  <td class="p-subject">
#  <a href="./selectBbsNttView.do;JSESSIONID=51EF6AC7E4896FA0BCCEB34182E3D608?key=815&amp;bbsNo=8&amp;nttNo=161037&amp;pageUnit=10&amp;searchCtgry=%ed%95%99%ec%82%ac%2f%ec%9e%a5%ed%95%99&amp;searchCnd=SJ&amp;searchKrwd=%ec%9e%a5%ed%95%99&amp;pageIndex=1" target="_top">
#
#
#
#
#
#  			                                            (재)고속도로장학재단 2025년 고속도로 장학생 선발 협조 요청
#
#
#
#
#
#  			                                            </a>
#  </td>
#  <td>
#  <span class="p-icon p-icon__pdf">pdf 파일 첨부</span>
#  </td>
#  <td>
#  			                                            학생과
#  			                                    </td>
#  <td>
#  <!--<time>
#
#
#
#  												                	2025-09-09
#
#
#  			                                            </time>-->
#  								    2025-09-09
#  			                                    </td>
#  <td class="hits" data-mask="#,##0" data-mask-reverse="true">
#  			                                            7
#  			                                    </td>
#  </tr>,
#  <tr>
#  <td>
#  <span class="bbs_num">344</span>
#  </td>
#
#  <td class="p-subject">
#  <a href="./selectBbsNttView.do;JSESSIONID=51EF6AC7E4896FA0BCCEB34182E3D608?key=815&amp;bbsNo=8&amp;nttNo=160989&amp;pageUnit=10&amp;searchCtgry=%ed%95%99%ec%82%ac%2f%ec%9e%a5%ed%95%99&amp;searchCnd=SJ&amp;searchKrwd=%ec%9e%a5%ed%95%99&amp;pageIndex=1" target="_top">
#
#
#
#
#
#  			                                            (재)삼원장학재단 제23기 후기 삼원 장학생 선발 안내
#
#
#
#
#
#  			                                            </a>
#  </td>
#  <td>
#  <span class="p-icon p-icon__folder">여러개의 파일 첨부</span>
#  </td>
#  <td>
#  			                                            학생과
#  			                                    </td>
#  <td>
#  <!--<time>
#
#
#
#  												                	2025-09-08
#
#
#  			                                            </time>-->
#  								    2025-09-08
#  			                                    </td>
#  <td class="hits" data-mask="#,##0" data-mask-reverse="true">
#  			                                            156
#  			                                    </td>
#  </tr>,
#  <tr>
#  <td>
#  <span class="bbs_num">343</span>
#  </td>
#
#  <td class="p-subject">
#  <a href="./selectBbsNttView.do;JSESSIONID=51EF6AC7E4896FA0BCCEB34182E3D608?key=815&amp;bbsNo=8&amp;nttNo=160935&amp;pageUnit=10&amp;searchCtgry=%ed%95%99%ec%82%ac%2f%ec%9e%a5%ed%95%99&amp;searchCnd=SJ&amp;searchKrwd=%ec%9e%a5%ed%95%99&amp;pageIndex=1" target="_top">
#
#
#
#
#
#  			                                            (재)인천인재평생교육진흥원 2025년 하반기 장학생 선발 안내
#
#
#
#
#
#  			                                            </a>
#  </td>
#  <td>
#  <span class="p-icon p-icon__folder">여러개의 파일 첨부</span>
#  </td>
#  <td>
#  			                                            학생과
#  			                                    </td>
#  <td>
#  <!--<time>
#
#
#
#  												                	2025-09-04
#
#
#  			                                            </time>-->
#  								    2025-09-04
#  			                                    </td>
#  <td class="hits" data-mask="#,##0" data-mask-reverse="true">
#  			                                            234
#  			                                    </td>
#  </tr>,
#  <tr>
#  <td>
#  <span class="bbs_num">342</span>
#  </td>
#
#  <td class="p-subject">
#  <a href="./selectBbsNttView.do;JSESSIONID=51EF6AC7E4896FA0BCCEB34182E3D608?key=815&amp;bbsNo=8&amp;nttNo=160885&amp;pageUnit=10&amp;searchCtgry=%ed%95%99%ec%82%ac%2f%ec%9e%a5%ed%95%99&amp;searchCnd=SJ&amp;searchKrwd=%ec%9e%a5%ed%95%99&amp;pageIndex=1" target="_top">
#
#
#
#
#
#  			                                            (재)경원장학재단 제6기 장학생 선발 안내
#
#
#
#
#
#  			                                            </a>
#  </td>
#  <td>
#  <span class="p-icon p-icon__pdf">pdf 파일 첨부</span>
#  </td>
#  <td>
#  			                                            학생과
#  			                                    </td>
#  <td>
#  <!--<time>
#
#
#
#  												                	2025-09-03
#
#
#  			                                            </time>-->
#  								    2025-09-03
#  			                                    </td>
#  <td class="hits" data-mask="#,##0" data-mask-reverse="true">
#  			                                            397
#  			                                    </td>
#  </tr>,
#  <tr>
#  <td>
#  <span class="bbs_num">341</span>
#  </td>
#
#  <td class="p-subject">
#  <a href="./selectBbsNttView.do;JSESSIONID=51EF6AC7E4896FA0BCCEB34182E3D608?key=815&amp;bbsNo=8&amp;nttNo=160873&amp;pageUnit=10&amp;searchCtgry=%ed%95%99%ec%82%ac%2f%ec%9e%a5%ed%95%99&amp;searchCnd=SJ&amp;searchKrwd=%ec%9e%a5%ed%95%99&amp;pageIndex=1" target="_top">
#
#
#
#
#
#  			                                            (재)경주시장학회 2025학년도 장학생 선발 안내
#
#
#
#
#
#  			                                            </a>
#  </td>
#  <td>
#  <span class="p-icon p-icon__pdf">pdf 파일 첨부</span>
#  </td>
#  <td>
#  			                                            학생과
#  			                                    </td>
#  <td>
#  <!--<time>
#
#
#
#  												                	2025-09-03
#
#
#  			                                            </time>-->
#  								    2025-09-03
#  			                                    </td>
#  <td class="hits" data-mask="#,##0" data-mask-reverse="true">
#  			                                            258
#  			                                    </td>
#  </tr>,
#  <tr>
#  <td>
#  <span class="bbs_num">340</span>
#  </td>
#
#  <td class="p-subject">
#  <a href="./selectBbsNttView.do;JSESSIONID=51EF6AC7E4896FA0BCCEB34182E3D608?key=815&amp;bbsNo=8&amp;nttNo=160822&amp;pageUnit=10&amp;searchCtgry=%ed%95%99%ec%82%ac%2f%ec%9e%a5%ed%95%99&amp;searchCnd=SJ&amp;searchKrwd=%ec%9e%a5%ed%95%99&amp;pageIndex=1" target="_top">
#
#
#
#
#
#  			                                            2025년 2학기 국가장학금 신청자 가구원 미동의자 동의 안내
#
#
#
#
#
#  			                                            </a>
#  </td>
#  <td>
#  <span class="p-icon p-icon__folder">여러개의 파일 첨부</span>
#  </td>
#  <td>
#  			                                            학생과
#  			                                    </td>
#  <td>
#  <!--<time>
#
#
#
#  												                	2025-09-02
#
#
#  			                                            </time>-->
#  								    2025-09-02
#  			                                    </td>
#  <td class="hits" data-mask="#,##0" data-mask-reverse="true">
#  			                                            307
#  			                                    </td>
#  </tr>,
#  <tr>
#  <td>
#  <span class="bbs_num">339</span>
#  </td>
#
#  <td class="p-subject">
#  <a href="./selectBbsNttView.do;JSESSIONID=51EF6AC7E4896FA0BCCEB34182E3D608?key=815&amp;bbsNo=8&amp;nttNo=160820&amp;pageUnit=10&amp;searchCtgry=%ed%95%99%ec%82%ac%2f%ec%9e%a5%ed%95%99&amp;searchCnd=SJ&amp;searchKrwd=%ec%9e%a5%ed%95%99&amp;pageIndex=1" target="_top">
#
#
#
#
#
#  			                                            국가유산진흥원  2025년 국가유산진흥원 전통 기·예능 분야 및 매장유산 관련 분야 우수 장학생 선발 안내
#
#
#
#
#
#  			                                            </a>
#  </td>
#  <td>
#  <span class="p-icon p-icon__folder">여러개의 파일 첨부</span>
#  </td>
#  <td>
#  			                                            학생과
#  			                                    </td>
#  <td>
#  <!--<time>
#
#
#
#  												                	2025-09-02
#
#
#  			                                            </time>-->
#  								    2025-09-02
#  			                                    </td>
#  <td class="hits" data-mask="#,##0" data-mask-reverse="true">
#  			                                            270
#  			                                    </td>
#  </tr>,
#  <tr>
#  <td>
#  <span class="bbs_num">338</span>
#  </td>
#
#  <td class="p-subject">
#  <a href="./selectBbsNttView.do;JSESSIONID=51EF6AC7E4896FA0BCCEB34182E3D608?key=815&amp;bbsNo=8&amp;nttNo=160781&amp;pageUnit=10&amp;searchCtgry=%ed%95%99%ec%82%ac%2f%ec%9e%a5%ed%95%99&amp;searchCnd=SJ&amp;searchKrwd=%ec%9e%a5%ed%95%99&amp;pageIndex=1" target="_top">
#
#
#
#
#
#  			                                            2025학년도 2학기 중소기업 취업연계 장학사업(희망사다리Ⅰ유형) 신규 장학생 신청 인내
#
#
#
#
#
#  			                                            </a>
#  </td>
#  <td>
#  <span class="p-icon p-icon__folder">여러개의 파일 첨부</span>
#  </td>
#  <td>
#  			                                            학생과
#  			                                    </td>
#  <td>
#  <!--<time>
#
#
#
#  												                	2025-09-02
#
#
#  			                                            </time>-->
#  								    2025-09-02
#  			                                    </td>
#  <td class="hits" data-mask="#,##0" data-mask-reverse="true">
#  			                                            354
#  			                                    </td>
#  </tr>,
#  <tr>
#  <td>
#  <span class="bbs_num">337</span>
#  </td>
#
#  <td class="p-subject">
#  <a href="./selectBbsNttView.do;JSESSIONID=51EF6AC7E4896FA0BCCEB34182E3D608?key=815&amp;bbsNo=8&amp;nttNo=160762&amp;pageUnit=10&amp;searchCtgry=%ed%95%99%ec%82%ac%2f%ec%9e%a5%ed%95%99&amp;searchCnd=SJ&amp;searchKrwd=%ec%9e%a5%ed%95%99&amp;pageIndex=1" target="_top">
#
#
#
#
#
#  			                                            한국산림복지진흥원 2025년 한국산림복지진흥원 녹색장학사업 장학생 선발 안내
#
#
#
#
#
#  			                                            </a>
#  </td>
#  <td>
#  <span class="p-icon p-icon__folder">여러개의 파일 첨부</span>
#  </td>
#  <td>
#  			                                            학생과
#  			                                    </td>
#  <td>
#  <!--<time>
#
#
#
#  												                	2025-09-01
#
#
#  			                                            </time>-->
#  								    2025-09-01
#  			                                    </td>
#  <td class="hits" data-mask="#,##0" data-mask-reverse="true">
#  			                                            375
#  			                                    </td>
#  </tr>,
#  <tr>
#  <td>
#  <span class="bbs_num">336</span>
#  </td>
#
#  <td class="p-subject">
#  <a href="./selectBbsNttView.do;JSESSIONID=51EF6AC7E4896FA0BCCEB34182E3D608?key=815&amp;bbsNo=8&amp;nttNo=160761&amp;pageUnit=10&amp;searchCtgry=%ed%95%99%ec%82%ac%2f%ec%9e%a5%ed%95%99&amp;searchCnd=SJ&amp;searchKrwd=%ec%9e%a5%ed%95%99&amp;pageIndex=1" target="_top">
#
#
#
#
#
#  			                                            (재)달서인재육성장학재단 2025학년도 하반기 장학생 선발
#
#
#
#
#
#  			                                            </a>
#  </td>
#  <td>
#  <span class="p-icon p-icon__folder">여러개의 파일 첨부</span>
#  </td>
#  <td>
#  			                                            학생과
#  			                                    </td>
#  <td>
#  <!--<time>
#
#
#
#  												                	2025-09-01
#
#
#  			                                            </time>-->
#  								    2025-09-01
#  			                                    </td>
#  <td class="hits" data-mask="#,##0" data-mask-reverse="true">
#  			                                            327
#  			                                    </td>
#  </tr>]
